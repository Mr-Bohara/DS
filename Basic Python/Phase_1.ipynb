# %%
#operators

# 1. arthmetic
print("arthmetic")
a = 6
b = 2

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**2)
print(a% 2)

# 2. comparison
print("comparision")
print(a==b)
print(a!=b)
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
print(a==5)


# 3.logical
print("logical operator")
age = 25
income = 45000
is_citizen = True

can_vote = (age >= 18) and (is_citizen == True)
print(can_vote)

gets_descont = (age < 18) or (age > 65)
print(gets_descont)

is_minor = not (age >= 18)
print(is_minor)

loan_approve = (income > 30000) and is_citizen and not(age < 21)
print(loan_approve)


# 4. assignment operator
print("assignment")

score = 100

score += 10
score -= 30
print(score)


#--- project ---
print((10+5)*2-3**2)
print(True and False or True)
print(144%12)

print("---calculater---")

math = float(input("Ehter math mask: "))
science = float(input("Enter science mask: "))
english = float(input("Enter Your english mask: "))

total = math + science + english
avarage = total / 3
percentage = (total / 300) * 100

print(f"Total number is {total}")
print(f"your avarage is {avarage:.2f}")
print(f"your percentage is {percentage:.1f}%")
print(f"passed: {avarage>= 60}")
# Out:
# arthmetic
# 8
# 4
# 12
# 3.0
# 3
# 0
# 36
# 0
# comparision
# False
# True
# True
# True
# False
# False
# False
# logical operator
# True
# False
# False
# True
# assignment
# 80
# 21
# True
# 0
# ---calculater---

# %%
#Chapter 2: input and output

#output
name = "alisha"
age = 22
city = 'Bajhang'
price = 5.22
quantity = 2

print(f"my name is {name} and I am {age} years old. I am from {city}.")
print(f"total price is {price * quantity}.")

#input
my_name = input("What is your name?\n")
print(my_name)

print("hello", "world", sep= "--")
# Out:
# my name is alisha and I am 22 years old. I am from Bajhang.
# total price is 10.44.
# dhanush
# hello--world

# %%
#chapter 1 - Variable and data types

#Interger
age = 23
year = 2024
temperature = -5

#float
price = 12.2
height = 5.5
pi = 3.14

#string
name = "Dhanush"
massage = "Hello, World!"
city = "Kathmandu"

#boolean -True or False only
is_student = True
is_nepal = False

print(age)

string = str(year)
print(type(string))

add = 12 + price
print(price)

strings = "12"
interger = int(strings)
print(type(interger))

result = True + True + False
print("this is result: ", result)
# Out:
# 23
# <class 'str'>
# 12.2
# <class 'int'>
# this is result:  2

# %%
#chapter 0

print("Hello, World")
print("I am learning python!")
print("programming is fun!")
# Out:
# Hello, World
# I am learning python!
# programming is fun!
